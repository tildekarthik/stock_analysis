# %% [markdown]
# # Visualize data quality of stocks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 100)

# %%
from stock_lib import read_stk_data, read_yaml,update_stk_sql
# Out:
# Using TensorFlow backend.

# %%
import sqlite3 as lite

# %%
stk_list = read_yaml('../configs/stocks.yml')
stk_list.append('NIFTY_50')

db_file = "../data/stock_data.db"

# %%
conn = lite.connect(db_file)
cur = conn.cursor()

# %%
l = []

for stk in stk_list:
    try:
        df = pd.read_sql_query('select * from '+stk,conn, index_col='Date')
        l.append([stk,len(df),df.shape[1],df.index[0],df.index[-1]])
    except:
        print("Error :"+stk)

# %%
df_summary = pd.DataFrame(l,columns=['symbol','records','columns','start_date','end_date'])

# %%
df_summary.sort_values(by='records')
# sns.jointplot(x='start_date',y='records',data=df_summary)

# %%
from datetime import date
from nsepy import get_history

# %%
st_date = date(2019,4,1)
end_date = date(2019,4,6)

# %%
get_history(symbol='NIFTY_50', start=st_date, end=end_date,index=True)

# %% [markdown]
# # Plot the candles using plotly

# %%
import plotly
plotly.__version__

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from datetime import datetime
#plotly.tools.set_credentials_file(username='akarthik', api_key='XWpZWL4wuzcN2jScPuOM')

# %%
df = pd.read_sql_query('select * from '+'HDFC',conn, index_col='Date')

# %%
df = df[df.index>'2017-01-01']
df.columns

# %%
trace = go.Ohlc(x=df.index,
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])
data = [trace]
py.iplot(data, filename='simple_candlestick')

# %% [markdown]
# # Bollinger the 2 sigma limits for pct change

# %%
df = pd.read_sql_query('select Date,Close from '+'HDFC',conn, index_col='Date')

# %%
df['pct_change']=df['Close'].pct_change(1)
df['sigma']=df['pct_change'].rolling(100).std()

df[df['pct_change'].apply(np.abs)>2*df['sigma']]
# Out:
#               Close  pct_change     sigma
# Date
# 2003-06-09   381.50    0.038519  0.017648
# 2003-06-13   387.10    0.052904  0.018504
# 2003-07-03   418.10    0.085692  0.021006
# 2003-08-12   478.75    0.057427  0.022864
# 2003-08-19   510.55    0.064089  0.024018
# 2003-08-21   481.40   -0.057741  0.024686
# 2003-09-24   505.50    0.051482  0.024421
# 2003-10-06   550.90    0.055364  0.024550
# 2003-12-24   665.35    0.070900  0.024156
# 2004-01-21   626.25   -0.046005  0.021474
# 2004-01-28   655.35    0.057613  0.022169
# 2004-02-20   647.70   -0.042572  0.021282
# 2004-03-01   641.75    0.052567  0.021103
# 2004-05-05   646.75    0.043566  0.020251
# 2004-05-11   607.85   -0.062394  0.020456
# 2004-05-12   582.20   -0.042198  0.020833
# 2004-05-14   544.95   -0.079399  0.022302
# 2004-05-17   505.65   -0.072117  0.023405
# 2004-05-18   590.45    0.167705  0.028888
# 2004-10-14   654.55   -0.051583  0.018576
# 2004-10-15   629.70   -0.037965  0.018935
# 2004-11-30   800.75    0.040476  0.018109
# 2004-12-01   769.30   -0.039276  0.018592
# 2017-07-28  1785.35    0.033069  0.013008
# 2017-10-25  1677.65   -0.025925  0.011081
# 2017-11-01  1754.30    0.027469  0.011329
# 2017-11-17  1705.50    0.024694  0.011627
# 2018-01-15  1871.20    0.062608  0.011803
# 2018-01-29  1967.60    0.031075  0.012165
# 2018-02-02  1903.85   -0.032375  0.012752
# 2018-02-05  1823.35   -0.042283  0.013428
# 2018-06-22  1906.75    0.025741  0.012416
# 2018-07-04  1922.50    0.022770  0.010998
# 2018-08-03  1977.50    0.023577  0.011115
# 2018-08-16  1891.20   -0.025908  0.010994
# 2018-09-14  1925.45    0.025375  0.011266
# 2018-09-17  1878.85   -0.024202  0.011431
# 2018-09-24  1718.70   -0.065619  0.013199
# 2018-09-25  1773.35    0.031797  0.013511
# 2018-10-01  1806.35    0.029553  0.014037
# 2018-10-05  1708.65   -0.039248  0.014529
# 2018-10-19  1660.25   -0.044625  0.015895
# 2018-10-31  1769.25    0.058227  0.017343
# 2018-11-02  1824.40    0.035414  0.017694
#
# [203 rows x 3 columns]

# %%
sns.distplot(df['pct_change'].dropna())

# %%
df[df['pct_change']<-.04].loc[:,['Close','pct_change']]

# %%
df['pct_change'].std()

# %%
df['pct_change'].mean()

# %%
df.iloc[-100:,:]['pct_change'].plot()

# %%
df.iloc[-100:,:]['Close'].plot()

# %%
df.tail()

# %% [markdown]
# # View and analyse stock prediction outputs

# %%
df = pd.read_csv('stocks10.csv')

# %%
df.groupby("Symbol").sum().sort_values(by='correct',ascending=False)
df[df['Date']>'2019-01-01'].groupby("Symbol").sum().sort_values(by='correct',ascending=False)
# Out:
#                 Close          y         pred   pred_chg  act_chg  correct  \
# Symbol
# TATAMOTORS   10724.95   11006.85   10639.2916   -85.6584   281.90       33
# SBIN         17551.85   17731.65   17359.7248  -192.1252   179.80       11
# NIFTY_50    669411.95  677940.95  666350.6880 -3061.2620  8529.00        7
# TCS         120270.95  121969.85  120046.2232  -224.7268  1698.90        7
# ITC          17372.70   17466.75   17222.8620  -149.8380    94.05        5
# RELIANCE     75672.00   78170.75   73011.7606 -2660.2394  2498.75       -9
# ICICIBANK    22408.25   22610.85   21692.3916  -715.8584   202.60      -11
# INFY         44357.70   45094.90   43392.6048  -965.0952   737.20      -17
#
#              profit
# Symbol
# TATAMOTORS   568.20
# SBIN          42.30
# NIFTY_50    2093.00
# TCS         1186.00
# ITC          217.85
# RELIANCE    -585.65
# ICICIBANK   -179.50
# INFY        -783.90

# %%
c = a.loc[:,['correct']].join(b.loc[:,['correct']],lsuffix='_a',rsuffix='_b')

# %%
# Set up the matplotlib figure
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(7, 5), sharex=True)
sns.barplot(y='correct_a',data=c,x=c.index,ax=ax1)
sns.barplot(y='correct_b',data=c,x=c.index,ax=ax2)
